# %%
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import numpy as np
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import pandas as pd
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage, AnnotationBbox)
from matplotlib.cbook import get_sample_data
from wordcloud import WordCloud,STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer
from pandas import DataFrame
from PIL import Image
from plotly import tools
from plotly.offline import init_notebook_mode,iplot,plot
from nrclex import NRCLex
from nltk.corpus import stopwords
from colorama import Fore, Back, Style
from io import BytesIO
import base64

# %%
#***************************DataFrame Sumsang*********************************
dfCount=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/tweetSentimentCount.csv')
df=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/TweetAfterProcess.csv')
Data_2021 = df['date'].reset_index(drop=True)
#***************************DataFrame Iphone*********************************
dfCountIp=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/tweetCountIphone.csv')
dfIphone=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/TweetIphone.csv')
Data_2021Ip = dfIphone['date'].reset_index(drop=True)



#***************************DataFrame Huawei*********************************
dfCountH=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/tweetCountHuawei.csv')
dfHuawei=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/TweetHuawei.csv')
Data_2021H = dfHuawei['date'].reset_index(drop=True)


#***************************DataFrame Oppo*********************************
dfCountO=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/tweetCountOppo.csv')
dfOppo=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/TweetOppo.csv')
Data_2021O = dfOppo['date'].reset_index(drop=True)



#***************************DataFrame XIAOMI*********************************
dfCountX=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/tweetCountXIAOMI.csv')
dfXi=pd.read_csv('C:/Users/pk/Desktop/projet/analyse/out_data/TweetXIAOMI.csv')
Data_2021X = dfXi['date'].reset_index(drop=True)

#*******************************************Word Cloud Sumsang********************
imgSumPositive  = Image.open('SumPositive.png') 
figSumPos = px.imshow(imgSumPositive)
figSumPos.update_layout(dragmode="drawrect",
                        title_text='Positive Tweet Sumsang')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

imgSumNegative  = Image.open('SumNegative.png') 
figSumNeg = px.imshow(imgSumNegative)
figSumNeg.update_layout(dragmode="drawrect",
                        title_text='Negative Tweet Sumsang')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}




#*******************************************Word Cloud Iphone********************
imgIphPositive  = Image.open('IphonePositive.png') 
figIphPos = px.imshow(imgIphPositive)
figIphPos.update_layout(dragmode="drawrect",
                        title_text='Positive Tweet Iphone')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

imgIphNegative  = Image.open('IphoneNegative.png') 
figIphNeg = px.imshow(imgIphNegative)
figIphNeg.update_layout(dragmode="drawrect",
                        title_text='Negative Tweet Iphone')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}





#*******************************************Word Cloud Huawei********************
imgHuPositive  = Image.open('HuaweiPositive.png') 
figHuPos = px.imshow(imgHuPositive)
figHuPos.update_layout(dragmode="drawrect",
                       title_text='Positive Tweet Huawei')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

imgHuNegative  = Image.open('HuaweiNegative.png') 
figHuNeg = px.imshow(imgHuNegative)
figHuNeg.update_layout(dragmode="drawrect",
                       title_text='Negative Tweet Huawei')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}






#*******************************************Images Oppo********************
imgOppoPositive  = Image.open('OppoPositive.png') 
figOppoPos = px.imshow(imgOppoPositive)
figOppoPos.update_layout(dragmode="drawrect",
                       title_text='Positive Tweet Oppo')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

imgOppoNegative  = Image.open('OppoNegative.png') 
figOppoNeg = px.imshow(imgOppoNegative)
figOppoNeg.update_layout(dragmode="drawrect",
                       title_text='Negative Tweet Oppo')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

#*******************************************Images XIAOMI********************
imgXIAOMIPositive  = Image.open('XIAOMIPositive.png') 
figXIAOMIPos = px.imshow(imgXIAOMIPositive)
figXIAOMIPos.update_layout(dragmode="drawrect",
                       title_text='Positive Tweet XIAOMI')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

imgXIAOMINegative  = Image.open('XIAOMINegative.png') 
figXIAOMINeg = px.imshow(imgXIAOMINegative)
figXIAOMINeg.update_layout(dragmode="drawrect",
                       title_text='Negative Tweet XIAOMI')
config = {
    "modeBarButtonsToAdd": [
        "drawline",
        "drawopenpath",
        "drawclosedpath",
        "drawcircle",
        "drawrect",
        "eraseshape",
    ]
}

# %%
import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State
from dash import Dash
import plotly.express as px

# the style arguments for the sidebar.
SIDEBAR_STYLE = {
    'position': 'fixed',
    'top': 0,
    'left': 0,
    'bottom': 0,
    'width': '20%',
    'padding': '20px 10px',
    'background-color': '#B0E0E6'
}

# the style arguments for the main content page.
CONTENT_STYLE = {
    'margin-left': '25%',
    'margin-right': '5%',
    'padding': '20px 10p',
    
}

TEXT_STYLE = {
    'textAlign': 'center',
    'color': '#191970'
}

CARD_TEXT_STYLE = {
    'textAlign': 'center',
    'color': '#000000'
}

sidebar = html.Div(
    [
        html.H2("Liste of market", className="display-4"),
        html.Hr(),
        dbc.Nav(
            [
                dbc.NavLink("Sumsang", href="/", active="exact"),
                dbc.NavLink("Iphone", href="/page-iphone", active="exact"),
                dbc.NavLink("Huawei", href="/page-huawei", active="exact"),
                dbc.NavLink("Oppo", href="/page-oppo", active="exact"),
                dbc.NavLink("XIAOMI", href="/page-xiaomi", active="exact"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
)

content_first_row = dbc.Row([
    dbc.Col(
        dbc.Card(
            [

                dbc.CardBody(
                    [
                        html.H4(id='card_title_1', children=['Positive Sentiment'], className='card-title',
                                style=CARD_TEXT_STYLE),
                    ]
                )
            ]
        ),
        md=3
    ),
    dbc.Col(
        dbc.Card(
            [

                dbc.CardBody(
                    [
                        html.H4('Negative Sentiment', className='card-title', style=CARD_TEXT_STYLE),
                    ]
                ),
            ]

        ),
        md=3
    ),
    dbc.Col(
        dbc.Card(
            [
                dbc.CardBody(
                    [
                        html.H4('Neutral Sentiment', className='card-title', style=CARD_TEXT_STYLE),
                    ]
                ),
            ]

        ),
        md=3
    ),
    dbc.Col(
        dbc.Card(
            [
                dbc.CardBody(
                    [
                        html.H4('All Sentiment', className='card-title', style=CARD_TEXT_STYLE),
                    ]
                ),
            ]
        ),
        md=3
    )
])

content_second_row = dbc.Row(
    [
        dbc.Col(
            dcc.Graph(id='graph_1'), md=6
        ),

        dbc.Col(
            dcc.Graph(id='graph_2'), md=6
        )
    ]
)

content_third_row = dbc.Row(
    [
        dbc.Col(
            dcc.Graph(id='graph_3'), md=6,
        ),
        dbc.Col(
            dcc.Graph(id='graph_4'), md=6
        )
    ]
)
content_fourth_row = dbc.Row(
    [
        dbc.Col(
            dcc.Graph(id='graph_5'), md=6
        ),
        dbc.Col(
            dcc.Graph(id='graph_6'), md=6
        )
    ]
)

content = html.Div(
    [
        html.H2('Analytics Dashboard Tweet', style=TEXT_STYLE),
        html.Hr(),
        content_first_row,
        content_second_row,
        content_third_row,
        content_fourth_row
    ],
    style=CONTENT_STYLE
)

#-----------------------------------------------------------------------------------------------------
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
app.layout = html.Div([
    dcc.Location(id="url"),
    sidebar,
    content
])

@app.callback(
    Output("graph_1", "figure"),
    [Input("url", "pathname")]
)
def update_graph_1(pathname):
    if pathname=="/":
        fig = px.pie(dfCount, values='Count', names='Sentiment',
                 title='Sentiment Scores',
                 hover_data=['Sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-iphone":
        fig = px.pie(dfCountIp, values='Count', names='Sentiment',
                 title='Sentiment Scores',
                 hover_data=['Sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-huawei":
        fig = px.pie(dfCountH, values='Count', names='Sentiment',
                title='Sentiment Scores',
                hover_data=['Sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label') 
    elif pathname=="/page-oppo":
        fig = px.pie(dfCountO, values='Count', names='Sentiment',
                 title='Sentiment Scores',
                 hover_data=['Sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-xiaomi":
        fig = px.pie(dfCountX, values='Count', names='Sentiment',
                 title='Sentiment Scores',
                 hover_data=['Sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    return fig

#-----------------------------------------------------------------------------------------------------      
@app.callback(
    Output("graph_2", "figure"),
    [Input("url", "pathname")]
)
def update_graph_2(pathname):
    if pathname=="/":
        fig = px.pie(df, names=df['sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-iphone":
        fig = px.pie(dfIphone, names=dfIphone['sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-huawei":
        fig = px.pie(dfHuawei, names=dfHuawei['sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-oppo":
        fig = px.pie(dfOppo, names=dfOppo['sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    elif pathname=="/page-xiaomi":
        fig = px.pie(dfXi, names=dfXi['sentiment'])
        fig.update_traces(textposition='inside', textinfo='percent+label')
    return fig
#-----------------------------------------------------------------------------------------------------    
@app.callback(
    Output("graph_3", "figure"),
    [Input("url", "pathname")]
)
def update_graph_3(pathname):
    if pathname=="/":
        fig = px.histogram(Data_2021, x=df["sentiment"], color=df["sentiment"])
        fig.update_layout(
            title_text='Sentiments per Month in 2021', # title of plot
            xaxis_title_text='Sentiment', # xaxis label
            yaxis_title_text='Number of tweets', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-iphone":
        fig = px.histogram(Data_2021Ip, x=dfIphone["sentiment"], color=dfIphone["sentiment"])
        fig.update_layout(
            title_text='Sentiments per Month in 2021', # title of plot
            xaxis_title_text='Sentiment', # xaxis label
            yaxis_title_text='Number of tweets', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-huawei":
        fig = px.histogram(Data_2021H, x=dfHuawei["sentiment"], color=dfHuawei["sentiment"])
        fig.update_layout(
            title_text='Sentiments per Month in 2021', # title of plot
            xaxis_title_text='Sentiment', # xaxis label
            yaxis_title_text='Number of tweets', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-oppo":
        fig = px.histogram(Data_2021O, x=dfOppo["sentiment"], color=dfOppo["sentiment"])
        fig.update_layout(
            title_text='Sentiments per Month in 2021', # title of plot
            xaxis_title_text='Sentiment', # xaxis label
            yaxis_title_text='Number of tweets', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-xiaomi":
        fig = px.histogram(Data_2021X, x=dfXi["sentiment"], color=dfXi["sentiment"])
        fig.update_layout(
            title_text='Sentiments per Month in 2021', # title of plot
            xaxis_title_text='Sentiment', # xaxis label
            yaxis_title_text='Number of tweets', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    return fig
#-----------------------------------------------------------------------------------------------------
@app.callback(
    Output("graph_4", "figure"),
    [Input("url", "pathname")]
)
def update_graph_4(pathname):
    if pathname=="/":
        fig = px.histogram(dfCount['Sentiment'], x=dfCount["Count"], color=dfCount["Sentiment"])
        fig.update_layout(
            title_text='All Sentiments', # title of plot
            xaxis_title_text='Number of tweets', # xaxis label
            yaxis_title_text='Sentiment', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-iphone":
        fig = px.histogram(dfCountIp['Sentiment'], x=dfCountIp["Count"], color=dfCountIp["Sentiment"])
        fig.update_layout(
            title_text='All Sentiments', # title of plot
            xaxis_title_text='Number of tweets', # xaxis label
            yaxis_title_text='Sentiment', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-huawei":
        fig = px.histogram(dfCountH['Sentiment'], x=dfCountH["Count"], color=dfCountH["Sentiment"])
        fig.update_layout(
            title_text='All Sentiments', # title of plot
            xaxis_title_text='Number of tweets', # xaxis label
            yaxis_title_text='Sentiment', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-oppo":
        fig = px.histogram(dfCountO['Sentiment'], x=dfCountO["Count"], color=dfCountO["Sentiment"])
        fig.update_layout(
            title_text='All Sentiments', # title of plot
            xaxis_title_text='Number of tweets', # xaxis label
            yaxis_title_text='Sentiment', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    elif pathname=="/page-xiaomi":
        fig = px.histogram(dfCountX['Sentiment'], x=dfCountX["Count"], color=dfCountX["Sentiment"])
        fig.update_layout(
            title_text='All Sentiments', # title of plot
            xaxis_title_text='Number of tweets', # xaxis label
            yaxis_title_text='Sentiment', # yaxis label
            bargap=0.2, 
            bargroupgap=0.1 )
    return fig
#-----------------------------------------------------------------------------------------------------
@app.callback(
    Output("graph_5", "figure"),
    [Input("url", "pathname")]
)
def update_graph_5(pathname):
    if pathname=="/":
        fg=figSumPos
    elif pathname=="/page-iphone":
        fg=figIphPos
    elif pathname=="/page-huawei":
        fg=figHuPos
    elif pathname=="/page-oppo":
        fg=figOppoPos
    elif pathname=="/page-xiaomi":
        fg=figXIAOMIPos
    return fg
#-----------------------------------------------------------------------------------------------------
@app.callback(
    Output("graph_6", "figure"),
    [Input("url", "pathname")]
)
def update_graph_6(pathname):
    if pathname=="/":
        fg=figSumNeg
    elif pathname=="/page-iphone":
        fg=figIphNeg
    elif pathname=="/page-huawei":
        fg=figHuNeg
    elif pathname=="/page-oppo":
        fg=figOppoNeg
    elif pathname=="/page-xiaomi":
        fg=figXIAOMINeg
    return fg
#-----------------------------------------------------------------------------------------------------

if __name__ == '__main__':
    app.run_server(port=8050)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Jun/2021 08:51:32] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jun/2021 08:51:37] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
